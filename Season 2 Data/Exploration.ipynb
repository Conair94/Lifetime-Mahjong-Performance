# %% [markdown]
# # Data Exploration Notebook
# Use this notebook for ad-hoc analysis and exploration. The nightly processing logic has been moved to the `processing` module.

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

# Ensure we can import from the processing directory
if 'processing' not in sys.path:
    sys.path.append(os.path.abspath('processing'))

from processing import data_loader, config

# Load Data
df_data, df = data_loader.load_data()
print("Data Loaded Successfully!")
df_data.tail()

# %%
# Example: Plot Net Profit again locally
df[config.BIG3 + ['guest']].plot(figsize=(16, 9))
plt.title('Net Profit (Exploration)')
plt.grid(True)
plt.show()
